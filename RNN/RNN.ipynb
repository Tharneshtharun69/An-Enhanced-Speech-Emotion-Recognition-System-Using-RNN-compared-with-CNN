# %%
import os
import numpy as np
import librosa
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
import joblib  # For saving and loading the label encoder

# Function to load and preprocess audio data
def load_data(dataset_path):
    features = []  # List to store feature vectors
    labels = []    # List to store corresponding labels
    for emotion in os.listdir(dataset_path):
        emotion_path = os.path.join(dataset_path, emotion)
        if os.path.isdir(emotion_path):
            for file in os.listdir(emotion_path):
                if file.endswith('.wav'):
                    file_path = os.path.join(emotion_path, file)
                    audio, sr = librosa.load(file_path, sr=None)  # Load audio file
                    mfcc = librosa.feature.mfcc(y=audio, sr=sr, n_mfcc=40)  # Extract MFCC features
                    mfcc_scaled = np.mean(mfcc.T, axis=0)  # Average MFCC coefficients
                    features.append(mfcc_scaled)
                    labels.append(emotion)
    return np.array(features), np.array(labels)

# Define the path to your dataset
dataset_path = r'F:\ABDUL\ABDUL 2024\EMOTION-DETETION-IN-AUDIO_CNN_RNN\Tess'

# Load the dataset
X, y = load_data(dataset_path)

# Encode the labels into numerical format
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the dataset into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Feature Standardization
X_train = (X_train - np.mean(X_train, axis=0)) / np.std(X_train, axis=0)
X_test = (X_test - np.mean(X_test, axis=0)) / np.std(X_test, axis=0)

# Reshape the data to fit the input requirements of an RNN (LSTM layer)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Build the RNN model using LSTM layers
model = tf.keras.Sequential([
    tf.keras.layers.LSTM(128, return_sequences=True, input_shape=(X_train.shape[1], 1)),  # LSTM layer
    tf.keras.layers.LSTM(128, return_sequences=False),  # LSTM layer
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(len(label_encoder.classes_), activation='softmax')
])

# Compile the model with Adam optimizer and sparse categorical crossentropy loss
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define EarlyStopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, restore_best_weights=True)

# Train the model on the training data
model.fit(X_train, y_train, epochs=150, batch_size=64, validation_data=(X_test, y_test), callbacks=[early_stopping])

# Save the trained model
model.save('emotion_detection_model_rnn.h5')
print('Model saved to disk.')

# Save the label encoder
label_encoder_path = 'label_encoder.pkl'
joblib.dump(label_encoder, label_encoder_path)
print(f'Label encoder saved to {label_encoder_path}.')

# Evaluate the model on the test data
y_pred = np.argmax(model.predict(X_test), axis=1)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')

# Print the classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))
# Out:
# Epoch 1/150
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.2860 - loss: 2.3208 - val_accuracy: 0.5946 - val_loss: 1.1899
# Epoch 2/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.6874 - loss: 0.9557 - val_accuracy: 0.8750 - val_loss: 0.4117
# Epoch 3/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8745 - loss: 0.3844 - val_accuracy: 0.8554 - val_loss: 0.4511
# Epoch 4/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.8903 - loss: 0.3407 - val_accuracy: 0.9411 - val_loss: 0.2090
# Epoch 5/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9237 - loss: 0.2157 - val_accuracy: 0.9214 - val_loss: 0.2741
# Epoch 6/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9362 - loss: 0.1879 - val_accuracy: 0.9536 - val_loss: 0.1983
# Epoch 7/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9445 - loss: 0.1769 - val_accuracy: 0.9518 - val_loss: 0.1841
# Epoch 8/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9494 - loss: 0.1430 - val_accuracy: 0.9518 - val_loss: 0.1886
# Epoch 9/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9514 - loss: 0.1454 - val_accuracy: 0.9393 - val_loss: 0.2144
# Epoch 10/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9500 - loss: 0.1314 - val_accuracy: 0.9554 - val_loss: 0.1744
# Epoch 11/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9591 - loss: 0.1265 - val_accuracy: 0.9393 - val_loss: 0.2179
# Epoch 12/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9586 - loss: 0.1087 - val_accuracy: 0.9500 - val_loss: 0.2172
# Epoch 13/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9635 - loss: 0.1277 - val_accuracy: 0.9446 - val_loss: 0.2026
# Epoch 14/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9605 - loss: 0.1086 - val_accuracy: 0.9554 - val_loss: 0.1822
# Epoch 15/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9499 - loss: 0.1446 - val_accuracy: 0.9179 - val_loss: 0.2780
# Epoch 16/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9556 - loss: 0.1236 - val_accuracy: 0.9500 - val_loss: 0.1904
# Epoch 17/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9600 - loss: 0.1226 - val_accuracy: 0.9411 - val_loss: 0.2162
# Epoch 18/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9601 - loss: 0.1229 - val_accuracy: 0.9446 - val_loss: 0.2056
# Epoch 19/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.9719 - loss: 0.0892 - val_accuracy: 0.9607 - val_loss: 0.1712
# Epoch 20/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9611 - loss: 0.1068 - val_accuracy: 0.9589 - val_loss: 0.1597
# Epoch 21/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9786 - loss: 0.0746 - val_accuracy: 0.9500 - val_loss: 0.2009
# Epoch 22/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9702 - loss: 0.0778 - val_accuracy: 0.9643 - val_loss: 0.1765
# Epoch 23/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9770 - loss: 0.0840 - val_accuracy: 0.9607 - val_loss: 0.1680
# Epoch 24/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9754 - loss: 0.0680 - val_accuracy: 0.9429 - val_loss: 0.2344
# Epoch 25/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9728 - loss: 0.0816 - val_accuracy: 0.9482 - val_loss: 0.1923
# Epoch 26/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9699 - loss: 0.0906 - val_accuracy: 0.9696 - val_loss: 0.1480
# Epoch 27/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9750 - loss: 0.0722 - val_accuracy: 0.9482 - val_loss: 0.1976
# Epoch 28/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9747 - loss: 0.0779 - val_accuracy: 0.9625 - val_loss: 0.1914
# Epoch 29/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9810 - loss: 0.0633 - val_accuracy: 0.9607 - val_loss: 0.1878
# Epoch 30/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.9819 - loss: 0.0566 - val_accuracy: 0.9589 - val_loss: 0.2154
# Epoch 31/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9765 - loss: 0.0590 - val_accuracy: 0.9679 - val_loss: 0.1571
# Epoch 32/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9788 - loss: 0.0628 - val_accuracy: 0.9554 - val_loss: 0.2035
# Epoch 33/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9688 - loss: 0.0777 - val_accuracy: 0.9554 - val_loss: 0.1985
# Epoch 34/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9829 - loss: 0.0425 - val_accuracy: 0.9518 - val_loss: 0.2110
# Epoch 35/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9768 - loss: 0.0567 - val_accuracy: 0.9571 - val_loss: 0.1993
# Epoch 36/150
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.9753 - loss: 0.0701 - val_accuracy: 0.9625 - val_loss: 0.1802
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 26.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved to disk.
# Label encoder saved to label_encoder.pkl.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# Accuracy: 96.96%
#
# Classification Report:
#                         precision    recall  f1-score   support
#
#               OAF_Fear       1.00      0.98      0.99        52
#  OAF_Pleasant_surprise       0.92      0.98      0.95        47
#                OAF_Sad       1.00      0.98      0.99        49
#              OAF_angry       0.97      1.00      0.99        37
#            OAF_disgust       0.95      0.95      0.95        39
#              OAF_happy       0.94      0.92      0.93        37
#            OAF_neutral       1.00      1.00      1.00        30
#              YAF_angry       0.92      0.97      0.95        37
#            YAF_disgust       0.97      0.95      0.96        39
#               YAF_fear       0.95      1.00      0.97        37
#              YAF_happy       0.95      0.90      0.92        40
#            YAF_neutral       1.00      1.00      1.00        43
# YAF_pleasant_surprised       1.00      0.95      0.97        40
#                YAF_sad       1.00      1.00      1.00        33
#
#               accuracy                           0.97       560
#              macro avg       0.97      0.97      0.97       560
#           weighted avg       0.97      0.97      0.97       560
